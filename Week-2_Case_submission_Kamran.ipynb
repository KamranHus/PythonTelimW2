# %% [markdown]
# ## It contains only models which had a new release every year between 1999 and 2008 - this was used as a proxy for the popularity of the car.

# %% [markdown]
# ### 1.Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 2.Import dataset of cars(also show top 5 colums,shape and columns name)

# %%
df = pd.read_excel('cars.xlsx')

# %%
df.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv   cty   hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f  21.0  30.0  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p  compact

# %%
df.shape
# Out:
# (234, 11)

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# ### 3. Find correlation between variables.

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot= True,linewidths=0.1,fmt = ".1f",vmin=-1, vmax=1)
plt.title("Correlaion between numeric variables")
plt.show()
# High positive correlation between Cty & Hwy; Cyl & Displ; Negative corr. between Cty & displ; City & Cyl

# %% [markdown]
# ### 4. Display relationship between highway miles per gallon and city miles per gallon
# * Use scatter in matplotlib
# * Interpret how variables correlated according to scatter

# %%
plt.scatter(df['hwy'], df['cty'])
# There's a strong correlation btw hwy & cty variables;

# %% [markdown]
# ### 5. Show distributions and scatters between all variables by type of drive train
# *  Which variables have the highest correlation? Guess it visually.
# *  Which variables have the lowest correlation? Guess it visually.

# %%
sns.pairplot(df, vars = ['displ', 'year', 'cty', 'hwy'],  hue="drv")
# (by default olaraq) all variables goturende error verdi. Ona gore ancaq numeric olanlari goturdum.

# %%
# Bir de bezi variable-larin data-tipinin probleme sebeb olacagini dusunub bu 2-sini cevirib etdim. Waarning olsa da, ishledi
df1 = df
df1["cyl"] = df1.cyl.astype('category')
df1["drv"] = df1.cyl.astype('category')
sns.pairplot(df, hue="drv")
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### 6. Which class has most observed in dataset.
# * Use countplot

# %%
sns.countplot(x="class", data = df)

# %% [markdown]
# ### 7. Visualize engine displacement by each class boxplot
# * Use boxplot

# %%
sns.boxplot(x="class", y="displ", data=df)

# %%
sns.boxplot(x="class", y="displ", hue="cyl", data=df)

# %% [markdown]
# ### 8. Do the same thing in violinplot

# %%
sns.violinplot(x="class", y="displ", data=df)
